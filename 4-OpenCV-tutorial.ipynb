# %% [markdown]
# ## Images in Computer
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Main Images Types
# ![image.png](attachment:image.png)

# %% [markdown]
# ## A Pixel
# ![image.png](attachment:image.png)

# %% [markdown]
# <h2>1 Opencv Basics</h2>
# <h3>How to load a image</h3>

# %%
import cv2 #imporing the opencv module

#img=cv2.imread('Samples/flower.jpg') #relative
img=cv2.imread(r'C:\Users\Migara Liyanage\Desktop\Advaced Python Workshop\DAY 02\codes\Samples\flower.jpg') #absolute 

#print(img[100,100])

img[:,100:105]=[255,255,255]

print(img.shape)

cv2.imshow('LIVE',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
img=cv2.imread('samples/flower.jpg')

cv2.rectangle(img,(20,20),(100,100),(0,255,0),2)

cv2.imshow('IMG',img)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
cv2.imwrite('flower.png',img)

# %% [markdown]
# <h3>How to load a video file</h3>

# %%
source=cv2.VideoCapture('Samples/facevideo.mp4')
#0-webcam
#1,2,3=usb camera
#myVideo.mp4-file
#124.35.32.43.643 p/w user name - wifi camera

ret,img=source.read()
print(ret)
cv2.imshow('IMG',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

source=cv2.VideoCapture('Samples/facevideo.mp4')
#0-webcam
#1,2,3=usb camera
#myVideo.mp4-file
#124.35.32.43.643 p/w user name - wifi camera
while(True):
    
    ret,img=source.read()
    cv2.rectangle(img,(20,20),(100,100),(0,255,0),-1)
    print(ret)
    if(ret==False):
        break
    
    cv2.imshow('IMG',img)
    key=cv2.waitKey(1)
    
    if(key==27):
        break
        
    
    
cv2.destroyAllWindows()
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %% [markdown]
# cv2.waitKey() is a keyboard binding function. Its argument is the time in milliseconds. The function waits for specified milliseconds for any keyboard event. If you press any key in that time, the program continues. If 0 is passed, it waits indefinitely for a key stroke. It can also be set to detect specific key strokes like, if key a is pressed etc which we will discuss below.
#
# read more about ```cv2.waitKey()``` function
#
# 1. [Keyboard ASCII values](https://progtpoint.blogspot.com/2017/06/key-board-ascii-key-code.html)
# 2. [OpenCV official Documentation](https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_gui/py_image_display/py_image_display.html#display-image)

# %% [markdown]
# ## Point Operations (Pixelwise Operations)
# ### Color Conversion

# %%
img=cv2.imread('Samples/flower.jpg')

img2=cv2.cvtColor(img,cv2.COLOR_BGR2YUV)

cv2.imshow('IMG',img)
cv2.imshow('IMG2',img2)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# There are more than 150 color-space conversion methods available in OpenCV. But we will look into only two which are most widely used ones, BGR \leftrightarrow Gray and BGR \leftrightarrow HSV.
#
# For color conversion, we use the function cv2.cvtColor(input_image, flag) where flag determines the type of conversion.
#
# For BGR \rightarrow Gray conversion we use the flags cv2.COLOR_BGR2GRAY. Similarly for BGR \rightarrow HSV, we use the flag cv2.COLOR_BGR2HSV. To get other flags, just run following commands in your Python terminal :
#
# ```
#
# >>> import cv2
# >>> flags = [i for i in dir(cv2) if i.startswith('COLOR_')]
# >>> print flags
#
# ```
#
# Read more about colorspaces
#
# 1. [Tutorialspoint Digital Image Processing](https://www.tutorialspoint.com/dip/grayscale_to_rgb_conversion.htm)
# 2. [HSV colorspace](https://en.wikipedia.org/wiki/HSL_and_HSV)

# %% [markdown]
# <h3>Image Thresholding</h3>
# <p>Here, the matter is straight forward. If pixel value is greater than a threshold value, it is assigned one value (may be white), else it is assigned another value (may be black). The function used is cv2.threshold. First argument is the source image, which should be a grayscale image. Second argument is the threshold value which is used to classify the pixel values. Third argument is the maxVal which represents the value to be given if pixel value is more than (sometimes less than) the threshold value. OpenCV provides different styles of thresholding and it is decided by the fourth parameter of the function. Different types are:</p>
#
# <table align="left">
#     <tr>
#         <th>cv2.THRESH_BINARY</th>
#     </tr>
#     <tr>
#         <th>cv2.THRESH_BINARY_INV</th>
#     </tr>
#     <tr>
#         <th>cv2.THRESH_TRUNCV</th>
#     </tr>
#     <tr>
#         <th>cv2.THRESH_TOZEROV</th>
#     </tr>
#     <tr>
#         <th>cv2.THRESH_TOZERO_INV</th>
#     </tr>
# </table>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('Samples/threshold.jpg')
plt.imshow(img,cmap='gray')

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap='gray')

# %%
ret,thresh=cv2.threshold(gray,60,255,cv2.THRESH_BINARY)
plt.imshow(thresh,cmap='gray')

# %%
ret,thresh=cv2.threshold(gray,100,255,cv2.THRESH_TOZERO)
plt.imshow(thresh,cmap='gray')

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('Samples/gray_image.png',0)

print(img[330,220])

plt.imshow(img,cmap='gray')
# Out:
# 30

# %%
ret,thresh=cv2.threshold(img,80,255,cv2.THRESH_BINARY)
plt.imshow(thresh,cmap='gray')
